# %% [markdown]
# # Understand Linear Regression

# %% [markdown]
# We are going to be working with a data set supplied to us from LendingClub.com from kaggle.com
#
# The goal will be to get a Loan Status Prediction.
#
# data from 2007 - 2017
#
# We follow these steps, something we will do in the future for other data sets as well.
#
# Browse the data
# Data cleanup
# Visual exploration
# Model derivation

# %% [markdown]
# ## 1 Browse the data

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
db = pd.read_csv('/Users/jasonbonvie/Desktop/GitHub/DataScience/lending-club/accepted_2007_to_2017Q3.csv')
# Out:
# /Users/jasonbonvie/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0,18,48,58,117,128,129,130,133,134,135,138,144,145,146) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
db.shape
# Out:
# (1646801, 150)

# %%
db.head(5)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  38098114        NaN    15000.0      15000.0          15000.0   60 months
# 1  36805548        NaN    10400.0      10400.0          10400.0   36 months
# 2  37842129        NaN    21425.0      21425.0          21425.0   60 months
# 3  37612354        NaN    12800.0      12800.0          12800.0   60 months
# 4  37662224        NaN     7650.0       7650.0           7650.0   36 months
#
#    int_rate  installment grade sub_grade       ...        \
# 0     12.39       336.64     C        C1       ...
# 1      6.99       321.08     A        A3       ...
# 2     15.59       516.36     D        D1       ...
# 3     17.14       319.08     D        D4       ...
# 4     13.66       260.20     C        C3       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# ...

# %%
pd.options.display.max_rows = 1000

# %%
db.head(10).T
# Out:
#                                                              0  \
# id                                                    38098114
# member_id                                                  NaN
# loan_amnt                                                15000
# funded_amnt                                              15000
# funded_amnt_inv                                          15000
# term                                                 60 months
# int_rate                                                 12.39
# installment                                             336.64
# grade                                                        C
# sub_grade                                                   C1
# emp_title                                           MANAGEMENT
# emp_length                                           10+ years
# home_ownership                                            RENT
# annual_inc                                               78000
# ...
